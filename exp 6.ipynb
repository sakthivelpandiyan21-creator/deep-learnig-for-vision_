# %% [markdown]
# <a href="https://colab.research.google.com/github/sakthivelpandiyan21-creator/deep-learnig-for-vision_/blob/main/exp%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

num_samples = 100
timesteps = 10
height, width, channels = 64, 64, 1

x_data = np.random.rand(num_samples, timesteps, height, width, channels)
y_data = np.random.randint(0, 3, size=(num_samples,))

# Flatten the spatial dimensions for the LSTM input
x_data = x_data.reshape(num_samples, timesteps, -1)

x_train, x_test = x_data[:80], x_data[80:]
y_train, y_test = y_data[:80], y_data[80:]

model = models.Sequential([
    # Use Input layer instead of input_shape in the first hidden layer
    layers.Input(shape=(timesteps, height * width * channels)),
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=8, validation_split=0.2)

loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc * 100:.2f}%")

sample = x_test[0:1]
predicted = model.predict(sample)
print("Predicted Class:", np.argmax(predicted))
# Out:
# Epoch 1/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.3594 - loss: 1.1591 - val_accuracy: 0.3750 - val_loss: 1.0443
# Epoch 2/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3594 - loss: 1.1084 - val_accuracy: 0.3750 - val_loss: 1.1016
# Epoch 3/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6406 - loss: 1.0164 - val_accuracy: 0.0625 - val_loss: 1.1276
# Epoch 4/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6406 - loss: 0.9661 - val_accuracy: 0.5000 - val_loss: 1.0446
# Epoch 5/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6406 - loss: 0.9452 - val_accuracy: 0.1250 - val_loss: 1.1810
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4500 - loss: 1.1255
# Test Accuracy: 45.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Predicted Class: 0
